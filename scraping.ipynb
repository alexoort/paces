# %%
import pandas as pd

infra_upgrades = pd.read_excel("MTEP24 Appendix A Tranche 2.1 Projects.xlsx", sheet_name="Facilities")

# first row should be header 

infra_upgrades.columns = infra_upgrades.iloc[0]
infra_upgrades = infra_upgrades.iloc[1:].reset_index(drop=True)


infra_upgrades.head()
# Out:
# 0 Target Appendix App ABC Planning Region  \
# 0     A in MTEP24       A            West
# 1     A in MTEP24       A            West
# 2     A in MTEP24       A            West
# 3     A in MTEP24       A            West
# 4     A in MTEP24       A            West
#
# 0 Geographic Location by TO Member System PrjID Facility ID Facility Type  \
# 0                 GRE, MP, MRES, OTP, XEL    19         NaN            LN
# 1                                     XEL    19         NaN           Sub
# 2                                     XEL    19         NaN           Sub
# 3                                     XEL    19         NaN            LN
# 4                                     XEL    19         NaN           Sub
#
# 0         Expected ISD          From Sub     To Sub  ... Share Status  \
# 0  2032-06-01 00:00:00  MN/ND State Line      Bison  ...          NaN
# 1  2032-06-01 00:00:00             Bison        NaN  ...          NaN
# 2  2032-06-01 00:00:00       Cass County        NaN  ...          NaN
# 3  2032-06-01 00:00:00       Cass County  Red River  ...          NaN
# 4  2032-06-01 00:00:00         Red River        NaN  ...          NaN
#
# 0 Other Type Transmission Project Type Previous Quarter Expected ISD  \
# 0        NaN                       NaN                           NaN
# 1        NaN                       NaN                           NaN
# 2        NaN                       NaN                           NaN
# 3        NaN                       NaN                           NaN
# 4        NaN                       NaN                           NaN
#
# 0 Previous Quarter Planning Status Previous Quarter Estimated Cost  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
#
# 0 Facility Cost Change % Cost Est. Variance In Service Date Change (Months)  \
# 0                    NaN                NaN                             NaN
# 1                    NaN                NaN                             NaN
# 2                    NaN                NaN                             NaN
# 3                    NaN                NaN                             NaN
# 4                    NaN                NaN                             NaN
#
# 0 Fac. Delay Reason
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 41 columns]

# %%
# include a mapping from state abbreviations to state names
state_abbreviations = {
    'TX': 'Texas',
    'CA': 'California',
    'AZ': 'Arizona',
    'NM': 'New Mexico',
    'OK': 'Oklahoma',
    'KS': 'Kansas',
    'NE': 'Nebraska',
    'MO': 'Missouri',
    'IA': 'Iowa',
    'MN': 'Minnesota',
    'WI': 'Wisconsin',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'OH': 'Ohio',
    'MI': 'Michigan',
    'PA': 'Pennsylvania',
    'NY': 'New York',
    'VA': 'Virginia',
    'NC': 'North Carolina',
    'SC': 'South Carolina',
    'GA': 'Georgia',
    'AL': 'Alabama',
    'TN': 'Tennessee',
    'AR': 'Arkansas',
    'LA': 'Louisiana',
    'MS': 'Mississippi',
    'KY': 'Kentucky',
    'WV': 'West Virginia',
    'MD': 'Maryland',
    'DE': 'Delaware',
    'NJ': 'New Jersey',
    'CT': 'Connecticut',
    'RI': 'Rhode Island',
    'MA': 'Massachusetts',
    'ME': 'Maine',
    'NH': 'New Hampshire',
    'VT': 'Vermont',
    'ID': 'Idaho',
    'WY': 'Wyoming',
    'MT': 'Montana',
    'ND': 'North Dakota',
    'SD': 'South Dakota',
    'NE': 'Nebraska',
    'IA': 'Iowa',
    'MO': 'Missouri',
    'AR': 'Arkansas',
    'OK': 'Oklahoma',
    'TX': 'Texas',
    'NM': 'New Mexico',
    'AZ': 'Arizona',
    'CA': 'California',
    'NV': 'Nevada', 
    'WA': 'Washington',
    'OR': 'Oregon',
    'UT': 'Utah',
    'ID': 'Idaho',
    'WY': 'Wyoming',
    'MT': 'Montana',
    'ND': 'North Dakota',
    'SD': 'South Dakota',
    'NE': 'Nebraska',
    'IA': 'Iowa',
    'MO': 'Missouri',
    'AR': 'Arkansas',
        }
print(len(set(state_abbreviations.keys())))
# Out:
# 46

# %%
import requests
import pandas as pd
from collections import defaultdict
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

def get_substations_for_state(state_name):
    """
    Fetch ALL named substations in a given state (admin_level=4).
    Returns a dict mapping substation_name -> list of (lat, lon).
    (We use a list because sometimes multiple OSM features may share the same name.)
    """
    logger.info(f"Fetching substations for state: {state_name}")
    overpass_url = "https://overpass-api.de/api/interpreter"
    
    query = f"""
    [out:json];
    area["name"="{state_name}"]["admin_level"="4"]->.searchArea;
    (
      node["power"="substation"]["name"](area.searchArea);
      way["power"="substation"]["name"](area.searchArea);
      relation["power"="substation"]["name"](area.searchArea);
    );
    out center;
    """
    
    response = requests.post(overpass_url, data={'data': query})
    response.raise_for_status()
    data = response.json()
    
    # Build a dictionary: name -> list of coordinates
    substation_dict = defaultdict(list)
    for el in data.get('elements', []):
        # name
        name = el.get('tags', {}).get('name', None)
        if not name:
            continue
        # coordinates
        if el['type'] == 'node':
            lat, lon = el['lat'], el['lon']
        else:
            # ways/relations => use 'center'
            center = el.get('center', {})
            lat, lon = center.get('lat'), center.get('lon')
        if lat is not None and lon is not None:
            substation_dict[name].append((lat, lon))
            logger.debug(f"Found substation: {name} at coordinates ({lat}, {lon})")
    
    logger.info(f"Found {len(substation_dict)} substations in {state_name}")
    return dict(substation_dict)

# Example usage with your dataframe 'infra_upgrades':
def populate_substation_coords(df):
    # Suppose df has columns: 'From Sub', 'To Sub', 'State'
    # And you want to append columns for from/to coords
    
    logger.info("Starting substation coordinate population")
    
    # Get unique states
    unique_states = df['State'].unique()
    logger.info(f"Processing {len(unique_states)} unique states")
    
    # Create a dictionary of state->(substation_name->coords_list)
    state_substations_cache = {}
    
    for st in unique_states:
        try:
            # Download data once per state
            state_name = state_abbreviations[st]
            logger.info(f"Processing state: {st} ({state_name})")
            station_lookup = get_substations_for_state(state_name)
            state_substations_cache[st] = station_lookup
            logger.info(f"Fetched {len(station_lookup)} unique substation names for state={st}")
        except Exception as e:
            logger.error(f"Error fetching data for state={st}: {e}")
            state_substations_cache[st] = {}
    
    # For each row, do a local lookup
    from_coords = []
    to_coords = []
    
    logger.info("Processing individual substations")
    for idx, row in df.iterrows():
        logger.debug(f"Processing row {idx}")
        # Expand the substation name if needed
        from_substation_name = f"{row['From Sub']} Substation"
        to_substation_name = f"{row['To Sub']} Substation" if pd.notna(row['To Sub']) else ""
        st = row['State']
        
        # default coordinate
        found_from = None
        found_to = None
        
        # Check if we have a dictionary for that state
        station_lookup = state_substations_cache.get(st, {})
        
        # Attempt exact matching or partial matching
        if from_substation_name in station_lookup:
            # If multiple coords found (multiple OSM features share the same name),
            # you can decide how to handle – e.g., pick the first
            found_from = station_lookup[from_substation_name][0]
            logger.debug(f"Found coordinates for {from_substation_name}: {found_from}")
        else:
            logger.debug(f"No coordinates found for {from_substation_name}")
        
        if to_substation_name in station_lookup:
            found_to = station_lookup[to_substation_name][0]
            logger.debug(f"Found coordinates for {to_substation_name}: {found_to}")
        elif to_substation_name:
            logger.debug(f"No coordinates found for {to_substation_name}")
        
        from_coords.append(found_from)
        to_coords.append(found_to)
    
    # 4) Attach to dataframe
    logger.info("Attaching coordinates to dataframe")
    df['From Sub Coordinates'] = from_coords
    df['To Sub Coordinates'] = to_coords

    logger.info("Finished populating substation coordinates")
    return df

# Then call it on your infra_upgrades dataframe
infra_upgrades = populate_substation_coords(infra_upgrades)
# Out:
# 2025-03-08 15:15:11,350 - INFO - Starting substation coordinate population
# 2025-03-08 15:15:11,400 - INFO - Processing 11 unique states
# 2025-03-08 15:15:11,401 - INFO - Processing state: ND (North Dakota)
# 2025-03-08 15:15:11,402 - INFO - Fetching substations for state: North Dakota
# 2025-03-08 15:15:41,384 - INFO - Found 134 substations in North Dakota
# 2025-03-08 15:15:41,397 - INFO - Fetched 134 unique substation names for state=ND
# 2025-03-08 15:15:41,398 - INFO - Processing state: MN (Minnesota)
# 2025-03-08 15:15:41,398 - INFO - Fetching substations for state: Minnesota
# 2025-03-08 15:16:14,050 - INFO - Found 525 substations in Minnesota
# 2025-03-08 15:16:14,055 - INFO - Fetched 525 unique substation names for state=MN
# 2025-03-08 15:16:14,056 - INFO - Processing state: WI (Wisconsin)
# 2025-03-08 15:16:14,056 - INFO - Fetching substations for state: Wisconsin
# 2025-03-08 15:16:46,812 - INFO - Found 556 substations in Wisconsin
# 2025-03-08 15:16:46,816 - INFO - Fetched 556 unique substation names for state=WI
# 2025-03-08 15:16:46,817 - INFO - Processing state: SD (South Dakota)
# 2025-03-08 15:16:46,818 - INFO - Fetching substations for state: South Dakota
# 2025-03-08 15:17:14,595 - INFO - Found 263 substations in South Dakota
# 2025-03-08 15:17:14,597 - INFO - Fetched 263 unique substation names for state=SD
# 2025-03-08 15:17:14,599 - INFO - Processing state: IA (Iowa)
# 2025-03-08 15:17:14,601 - INFO - Fetching substations for state: Iowa
# 2025-03-08 15:17:48,390 - INFO - Found 528 substations in Iowa
# 2025-03-08 15:17:48,406 - INFO - Fetched 528 unique substation names for state=IA
# 2025-03-08 15:17:48,407 - INFO - Processing state: IL (Illinois)
# 2025-03-08 15:17:48,407 - INFO - Fetching substations for state: Illinois
# 2025-03-08 15:18:21,206 - INFO - Found 417 substations in Illinois
# 2025-03-08 15:18:21,208 - INFO - Fetched 417 unique substation names for state=IL
# 2025-03-08 15:18:21,208 - INFO - Processing state: MI (Michigan)
# 2025-03-08 15:18:21,209 - INFO - Fetching substations for state: Michigan
# 2025-03-08 15:18:55,870 - INFO - Found 1870 substations in Michigan
# 2025-03-08 15:18:55,873 - INFO - Fetched 1870 unique substation names for state=MI
# 2025-03-08 15:18:55,873 - INFO - Processing state: IN (Indiana)
# 2025-03-08 15:18:55,873 - INFO - Fetching substations for state: Indiana
# 2025-03-08 15:19:34,758 - INFO - Found 540 substations in Indiana
# 2025-03-08 15:19:34,763 - INFO - Fetched 540 unique substation names for state=IN
# 2025-03-08 15:19:34,764 - INFO - Processing state: KY (Kentucky)
# 2025-03-08 15:19:34,764 - INFO - Fetching substations for state: Kentucky
# 2025-03-08 15:20:04,263 - INFO - Found 210 substations in Kentucky
# 2025-03-08 15:20:04,266 - INFO - Fetched 210 unique substation names for state=KY
# 2025-03-08 15:20:04,268 - INFO - Processing state: OH (Ohio)
# 2025-03-08 15:20:04,269 - INFO - Fetching substations for state: Ohio
# 2025-03-08 15:20:47,560 - INFO - Found 734 substations in Ohio
# 2025-03-08 15:20:47,562 - INFO - Fetched 734 unique substation names for state=OH
# 2025-03-08 15:20:47,562 - INFO - Processing state: MO (Missouri)
# 2025-03-08 15:20:47,563 - INFO - Fetching substations for state: Missouri
# 2025-03-08 15:21:18,330 - INFO - Found 288 substations in Missouri
# 2025-03-08 15:21:18,339 - INFO - Fetched 288 unique substation names for state=MO
# 2025-03-08 15:21:18,340 - INFO - Processing individual substations
# 2025-03-08 15:21:18,362 - INFO - Attaching coordinates to dataframe
# 2025-03-08 15:21:18,364 - INFO - Finished populating substation coordinates

# %%
infra_upgrades
# Out:
# 0   Target Appendix App ABC Planning Region  \
# 0       A in MTEP24       A            West
# 1       A in MTEP24       A            West
# 2       A in MTEP24       A            West
# 3       A in MTEP24       A            West
# 4       A in MTEP24       A            West
# ..              ...     ...             ...
# 317     A in MTEP24       A         Central
# 318     A in MTEP24       A         Central
# 319     A in MTEP24       A         Central
# 320     A in MTEP24       A         Central
# 321     A in MTEP24       A         Central
#
# 0   Geographic Location by TO Member System PrjID Facility ID Facility Type  \
# 0                   GRE, MP, MRES, OTP, XEL    19         NaN            LN
# 1                                       XEL    19         NaN           Sub
# 2                                       XEL    19         NaN           Sub
# 3                                       XEL    19         NaN            LN
# 4                                       XEL    19         NaN           Sub
# ..                                      ...   ...         ...           ...
# 317                  AEP (PJM), ComEd (PJM)    42         NaN            LN
# 318                                  NIPSCO    42         NaN           Sub
# 319                                  NIPSCO    42         NaN            LN
# 320                                  NIPSCO    42         NaN            LN
# 321                                  NIPSCO    42         NaN           Sub
#
# 0           Expected ISD          From Sub     To Sub  ...  \
# 0    2032-06-01 00:00:00  MN/ND State Line      Bison  ...
# 1    2032-06-01 00:00:00             Bison        NaN  ...
# 2    2032-06-01 00:00:00       Cass County        NaN  ...
# 3    2032-06-01 00:00:00       Cass County  Red River  ...
# 4    2032-06-01 00:00:00         Red River        NaN  ...
# ..                   ...               ...        ...  ...
# 317  2032-06-01 00:00:00           Babcock        NaN  ...
# 318  2032-06-01 00:00:00          Burr Oak        NaN  ...
# 319  2032-06-01 00:00:00          Burr Oak   Schahfer  ...
# 320  2032-06-01 00:00:00          Burr Oak        NaN  ...
# 321  2032-06-01 00:00:00          Schahfer        NaN  ...
#
# 0   Transmission Project Type Previous Quarter Expected ISD  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ..                        ...                           ...
# 317                       NaN                           NaN
# 318                       NaN                           NaN
# 319                       NaN                           NaN
# 320                       NaN                           NaN
# 321                       NaN                           NaN
#
# 0   Previous Quarter Planning Status Previous Quarter Estimated Cost  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 317                              NaN                             NaN
# 318                              NaN                             NaN
# 319                              NaN                             NaN
# 320                              NaN                             NaN
# 321                              NaN                             NaN
#
# 0   Facility Cost Change % Cost Est. Variance In Service Date Change (Months)  \
# 0                      NaN                NaN                             NaN
# 1                      NaN                NaN                             NaN
# 2                      NaN                NaN                             NaN
# 3                      NaN                NaN                             NaN
# 4                      NaN                NaN                             NaN
# ..                     ...                ...                             ...
# 317                    NaN                NaN                             NaN
# 318                    NaN                NaN                             NaN
# 319                    NaN                NaN                             NaN
# 320                    NaN                NaN                             NaN
# 321                    NaN                NaN                             NaN
#
# 0   Fac. Delay Reason       From Sub Coordinates         To Sub Coordinates
# 0                 NaN                       None  (46.9507742, -97.0758717)
# 1                 NaN  (46.9507742, -97.0758717)                       None
# 2                 NaN   (46.875282, -96.8498435)                       None
# 3                 NaN   (46.875282, -96.8498435)   (46.8804615, -96.808145)
# 4                 NaN   (46.8804615, -96.808145)                       None
# ..                ...                        ...                        ...
# 317               NaN  (41.5339647, -87.1022387)                       None
# 318               NaN  (41.2576945, -86.4225728)                       None
# 319               NaN  (41.2576945, -86.4225728)                       None
# 320               NaN  (41.2576945, -86.4225728)                       None
# 321               NaN                       None                       None
#
# [322 rows x 43 columns]

# %%
# save file as csv
infra_upgrades.to_csv('infra_upgrades_coordinates.csv', index=False)
